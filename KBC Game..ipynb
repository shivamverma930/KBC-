# %% [markdown]
# # KBC Game

# %%
q = ["Which of the following states doesn’t share its boundary with Gujarat?",
     "According to Indian Mythology, Kans, the brother of Devaki was the ruler of which city?",
     "Who wrote the play “Romeo and Juliet”?",
     "Who is the current Prime Minister of Canada?",
     "Which state in India is also known as “Dev Bhoomi”?",
     "Which Indian Cricketer has the record for scoring the most number of ODI centuries?",
     "What is the name of the famous poet who wrote India’s national anthem “Jana Gana Mana”?",
     "The first ever full-length Gujarati movie is based on the life of which of the following personalities?",
     "Which of the following Prime ministers of India was born in present-day Gujarat?",
     "Which of the following Bollywood superstars lives in a Bungalow called Mannat?",
    "What is the primary ingredient in traditional French béchamel sauce?",
    "What platform is the most often used for video game live streaming?",
    "In which novel does the character Atticus Finch appear?",
    "What feature did Instagram introduce in 2016 to compete with",
    "How many bones are there in the adult human body?"]

# %%
op = [["Maharashtra","Rajasthan","Madhya Pradesh","Goa"],
    ["Mathura","Dwarka","Indraprastha","Ujjain"],
    ["Oscar Wilde","William Shakespeare","Jane Austen","F. Scott Fitzgerald"],
    ["Boris Johnson","Angela Merkel","Justin Trudeau","Emmanuel Macron"],
    ["Uttarakhand","Rajasthan","Himachal Pradesh","Arunachal Pradesh"],
    ["Sachin Tendulkar","ViratKohli","Rohit Sharma","Rahul Dravid"],
    ["Bankim Chandra Chattopadhyay","Rabindranath Tagore","Muhammad Iqbal","Sarojini Naidu"],
    ["Narsi Mehta"," Premchand Bhatt","Mahatma Gandhi","Mira Bai"],
    [" Chaudhary Charan Singh","Gulzarilal Nanda","Morarji Desai","Jawaharlal Nehru"],
    ["Salman Khan","Aamir Khan","Amitabh Bachchan","Shahrukh Khan"],
    ["Chicken broth","Fish stock","Milk","Tomato"],
    ["Twitch","YouTube","Facebook Live","Vimeo"],
    ["Catcher in the Rye","To Kill a Mockingbird","The Great Gatsby","1984"],
    ["Stories","Reels","IGTV","Live Streaming"],
    ["186","206","226","246"]]

# %%
crt = ["Goa","Mathura","William Shakespeare","Justin Trudeau","Uttarakhand","ViratKohli","Rabindranath Tagore","Narsi Mehta"," Morarji Desai","Shahrukh Khan","Milk","Twitch","To Kill a Mockingbird","Stories","206"]

# %%
pm = [100000,200000,300000,400000,500000,600000,700000,800000,900000,1000000,1100000,1200000,1300000,1400000,1500000]

# %%
print("*************** Welcome To KBC Game ***************")
input("Enter The Your Name :- ")
print()
count = 0
score = 0
quesno  = 0
for i in range(len(q)):
    print(f'{i+1}.',q[i])
    quesno += 1
    print(quesno)
    for j in range(4):
        print(f'{j+1})',op[i][j])
    print()
    a = int(input("Enter Your Answer :- "))
    tep = op[i][a-1]
    print(tep)
    if(tep==crt[i]):
        print("You Are Right :- Move On Next Question.....")
        fpm = pm[i]
        print("Your Final Prize Money is :- ", fpm)
    else:
        print("You Are Wrong :- Sorry.....")
        print()
        if(quesno>=1 and quesno<=5):
            fpm = 0
            print(quesno)
        elif quesno>5 and quesno<=10:
            fpm = pm[4]
            print(quesno)
        elif quesno> 10 and quesno<=15:
            fpm = pm[9]
            print(quesno)
        print("Your Final Prize Money is :- ", fpm)
        break
    print()
    b = input("Do You Want To Continue :- (yes/no)")
    if(b=="yes"):  
        print(b)
    else:  
        print("No")
        print("Your Final Prize Money is :- ", pm[i-1])
        break
        
print("Your Finally Score is :-", score)
print("Your Finally Price money is :- ", count)
# Out:
# *************** Welcome To KBC Game ***************
# Enter The Your Name :- vdjnvi
#
# 1. Which of the following states doesn’t share its boundary with Gujarat?
# 1
# 1) Maharashtra
# 2) Rajasthan
# 3) Madhya Pradesh
# 4) Goa
#
# Enter Your Answer :- 4
# Goa
# You Are Right :- Move On Next Question.....
# Your Final Prize Money is :-  100000
#
# Do You Want To Continue :- (yes/no)yes
# yes
# 2. According to Indian Mythology, Kans, the brother of Devaki was the ruler of which city?
# 2
# 1) Mathura
# 2) Dwarka
# 3) Indraprastha
# 4) Ujjain
#
# Enter Your Answer :- 1
# Mathura
# You Are Right :- Move On Next Question.....
# Your Final Prize Money is :-  200000
#
# Do You Want To Continue :- (yes/no)yes
# yes
# 3. Who wrote the play “Romeo and Juliet”?
# 3
# 1) Oscar Wilde
# 2) William Shakespeare
# 3) Jane Austen
# 4) F. Scott Fitzgerald
#
# Enter Your Answer :- 2
# William Shakespeare
# You Are Right :- Move On Next Question.....
# Your Final Prize Money is :-  300000
#
# ...
